# %% [markdown]
# <a href="https://colab.research.google.com/github/akashsngg99/data-Engineer-Pyspark/blob/main/snowpark_gcp_interview_all.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pyspark
# !pip install snowflake-snowpark-python
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 450.4/450.4 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 16.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.0/105.0 kB 14.6 MB/s eta 0:00:00
# ...

# %%
import file
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-f5da65cb6f61> in <cell line: 1>()
# ----> 1 import file
#
# ModuleNotFoundError: No module named 'file'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
fopen=open("searchdata.txt","r")
for each in fopen:
  print (each)
# Python code to illustrate with()
# Out:
# best big data hadoop spark training
# kelly technologies courses
# intellepaat
# cloudera training partner india
# microsoft certification courses in big data
# big data online preparation
# BIG DATA COURSE IN DELHI
# online data mining certification programs
# acadgild
# BIG DATA coursera module 1
# PYTHON training in chennai
# hadoop developer
# microsoft big data certification
# hadoop training in delhi
# big data courses in hyderabad online
# computer data course
# big data HADOOP training report
# DATA analytics course in bangalore
# cloudera certified professional
# apache hadoop institute in delhi
# good apache spark classes
# spark interview questions
# big data contents
# b tech comp sc big data
# third class of analytics for all master the basics of analytics in 5 days session is starting in 5www gs im n qjavq5catum
# training in chennai
# cloudx lab
# edureka credentials
# big data coarse
# big data ecosystems
# big data intoduction course
# ...

# %%
words=[]
with open("searchdata.txt") as file:
	data = file.read()

words=data.split()
print(words)
# Out:
# ['best', 'big', 'data', 'hadoop', 'spark', 'training', 'kelly', 'technologies', 'courses', 'intellepaat', 'cloudera', 'training', 'partner', 'india', 'microsoft', 'certification', 'courses', 'in', 'big', 'data', 'big', 'data', 'online', 'preparation', 'BIG', 'DATA', 'COURSE', 'IN', 'DELHI', 'online', 'data', 'mining', 'certification', 'programs', 'acadgild', 'BIG', 'DATA', 'coursera', 'module', '1', 'PYTHON', 'training', 'in', 'chennai', 'hadoop', 'developer', 'microsoft', 'big', 'data', 'certification', 'hadoop', 'training', 'in', 'delhi', 'big', 'data', 'courses', 'in', 'hyderabad', 'online', 'computer', 'data', 'course', 'big', 'data', 'HADOOP', 'training', 'report', 'DATA', 'analytics', 'course', 'in', 'bangalore', 'cloudera', 'certified', 'professional', 'apache', 'hadoop', 'institute', 'in', 'delhi', 'good', 'apache', 'spark', 'classes', 'spark', 'interview', 'questions', 'big', 'data', 'contents', 'b', 'tech', 'comp', 'sc', 'big', 'data', 'third', 'class', 'of', 'analytics', '
# ...

# %%
import re
from collections import Counter
word_counts = Counter(words)
print(word_counts)
# Out:
# Counter({'data': 354, 'big': 279, 'in': 169, 'training': 111, 'course': 104, 'hadoop': 96, 'online': 58, 'courses': 53, 'spark': 42, 'bangalore': 38, 'analytics': 35, 'hyderabad': 33, 'for': 30, 'best': 29, 'of': 27, 'certification': 26, 'and': 22, 'to': 21, 'with': 21, 'chennai': 20, 'institute': 19, 'bigdata': 19, 'india': 16, 'apache': 15, 'learn': 15, 'tutorial': 15, 'the': 12, 'is': 12, 'learning': 12, 'institutes': 12, 'classes': 11, 'edureka': 11, 'analyst': 11, 'placement': 11, 'intellipaat': 10, 'scala': 10, 'iit': 10, 'fees': 10, 'coursera': 9, 'engineering': 9, 'engineer': 9, 'by': 9, 'delhi': 8, 'python': 8, 'top': 8, 'from': 8, 'fee': 8, 'which': 8, 'pune': 8, 'DATA': 7, 'pg': 7, 'program': 7, 'on': 7, 'architect': 7, 'cloudera': 6, 'BIG': 6, 'class': 6, 'beginners': 6, 'com': 6, 'reviews': 6, 'coaching': 6, 'simplilearn': 6, 'ameerpet': 6, 'cost': 6, 'dataflair': 6, 'near': 6, '1': 5, 'academy': 5, 'cloudxlab': 5, 'study': 5, '2020': 5, 'analysis': 5, 'projects': 5, 'a'
# ...
